# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Boniface Ibe Iwuagwu**

# %% [markdown]
# Data Analyst

# %% [markdown]
# *I am interested in Data Science because I want to acquire the necessary skills required to solve Big Data problems using AI and other machine learning tools.*
# *I also want to use the knowledge from Data Science to improve my Data Analytic skills*

# %% [markdown]
# ### My code will subtract the number 70 from 100

# %%
print("100 - 70 is", 100-70)
# Out:
# 100 - 70 is 30

# %% [markdown]
# ## Activities I Covered in Week 4

# %% [markdown]
# * Create and Share Your Jupyter Notebook
# * Peer Graded Assignment
# * Submit Your Work and Grade Your Peers
# * Review your Peers
